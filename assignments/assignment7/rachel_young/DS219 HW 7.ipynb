# %% [markdown]
# # Assignment 7

# %% [markdown]
# **Name:** Rachel Young

# %% [markdown]
# ## 1. Importing Data and Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing math scores
file_path_math = "student-mat.csv"
df = pd.read_csv(file_path_math, sep =';')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# see the basic statistics of the numerical data columns
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
#Graph the distribution of the students from each school 
ax = sns.barplot(x = df['school'].value_counts().index, y = df['school'].value_counts(), data = df)
ax.bar_label(ax.containers[0]) 
plt.title("Number of Students by School")
plt.xlabel("School")
plt.ylabel('Number of Students')
# Out:
# Text(0, 0.5, 'Number of Students')

# %%
#graph the gender distribution of the dataset
gender = sns.barplot(x = df['sex'].value_counts().index, y = df['sex'].value_counts(), data = df)
gender.bar_label(gender.containers[0]) 
plt.title("Number of Students by Gender")
plt.xlabel("Gender")
plt.ylabel('Number of Students')
# Out:
# Text(0, 0.5, 'Number of Students')

# %%
#graph the distribution of the number of failures among students 
failures = sns.barplot(x = df['failures'].value_counts().index, y = df['failures'].value_counts(), data = df)
failures.bar_label(failures.containers[0]) 
plt.title("Number of Students by Number of Failures")
plt.xlabel("Failures")
plt.ylabel('Number of Students')
# Out:
# Text(0, 0.5, 'Number of Students')

# %%
#correlations between features of the dataset 
corr = df.iloc[:, :].corr()
plt.figure(figsize=(30, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Summary Statistics
# * There are 395 students in the math scores dataset
# * There is an over representation of students from the GP, or Gabriel Pereira, school with 349 students and 49 students from Mousinho da Silveira
# * The number of students by gender are evenly distributed at a 208:187 ratio F:M.
# * Most students have not failed in the past with 312 students with 0 failures out of 395 students.

# %% [markdown]
# ## 3. Hypothesis Formulation

# %% [markdown]
# ### Hypothesis 1: There is a correlation between failures and final grade
# The feature named 'failures' represents the number of past class failures (numeric: n if 1<=n<3, else 4) and the column 'G3' represents final grade (numeric: from 0 to 20). Observing that the two variables have a high correlation coefficient in the correlation matrix mapped above in the EDA, I hypothesize that theses two variables are correlated to each other with the relationship that students with greater past failures will have lower final grades.

# %% [markdown]
# ### Hypothesis 2: There is a correlation between mother's education and final grade
# The column named 'studytime' represents the students mother's education on a numeric scale: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education). Since the columns 'Medu' and 'G3' have a high correlation coefficient in the correlation matrix above, I hypothesize that students whose mother's have a higher level of education will have higher median final grades.

# %% [markdown]
# ## 4. Hypothesis Testing

# %% [markdown]
# ### Hypothesis 1: There is a correlation between failures and final grade

# %%
#create box plot to graph distribution of final grades
sns.boxplot(x='failures', y='G3', data=df)
plt.title('Math: Box Plot of Past Failures and Final Grade')
plt.xlabel('Past Failures')
plt.ylabel('Final Grade')
# Out:
# Text(0, 0.5, 'Final Grade')

# %%
#Create pivot table with descriptive statistics
fail = df.pivot_table(index=['failures'], values=['G3'],
                       aggfunc={'median', 'mean', 'min', 'count'})
fail
# Out:
#             G3
#          count       mean median min
# failures
# 0          312  11.253205   11.0   0
# 1           50   8.120000    9.0   0
# 2           17   6.235294    8.0   0
# 3           16   5.687500    7.0   0

# %% [markdown]
# **Interpretation**
#
# From the boxplot, we can see that for final grades in math the more past failures you have, the lower the median final grade is. For example, the median score for students with no failures is 11, but the median scores for those with past failures are descending values between 9 and 7. However, it can be seen that the interquartile range for higher number of failures (3 or 4) is wider and shows greater variability, which means that there is still a wide range of grades that students with 3 or 4 failures can have from about 9 to nearly 0. However, based on the trend in the medians I would say there is a correlation between the two variables.

# %% [markdown]
# ### Hypothesis 2: There is a correlation between mother's education and final grade

# %%
#create box plot to graph distribution of final grades
sns.boxplot(x='Medu', y='G3', data=df)
plt.title("Math: Box Plot of Mother's Education and Final Grade")
plt.xlabel("Mother's Education")
plt.ylabel('Final Grade')
# Out:
# Text(0, 0.5, 'Final Grade')

# %%
#Create pivot table with descriptive statistics
medu = df.pivot_table(index=['Medu'], values=['G3'],
                       aggfunc={'median', 'mean', 'min', 'count'})
medu
# Out:
#         G3
#      count       mean median min
# Medu
# 0        3  13.000000   15.0   9
# 1       59   8.677966   10.0   0
# 2      103   9.728155   11.0   0
# 3       99  10.303030   10.0   0
# 4      131  11.763359   12.0   0

# %% [markdown]
# **Interpretation**
#
# From the boxplot we can see that students with mother's with the highest level of education (4 - higher education) have a higher median final grade at 12, but there is less of a pattern for the median grades of students with mother's who have education levels lower than that. As seen in the pivot table, for mothers with levels of 1,2, and 3 of education, the median values are about the same at 10, 11, and 10, which breaks the pattern of a positive relationship between mother's education and final grade. Also there are only 3 students with mother's who have no formal education, which can represent bias in our sample where individuals whose parents have low level of education may not have the resources necessary to be well represented in the two schools sampled from. This proves my hypothesis wrong, but there may be a relationship between final grades and whether student's mothers attended higher education specifically. There may be less of a pattenrn of differences in final grades for students with mothers that have education levels lower than higher education.

# %% [markdown]
# ## 5. Documentation and Reporting

# %% [markdown]
# ### Choosing the Dataset
# I chose this dataset because I thought it would be interesting to be able to understand features that impact students academic performance. Generally, academic performance is thought to be a result of studying more, but I thought the other demographic and background features measured in the dataset would be interesting, such as past class failures and parent's highest  education level. I was interested in understanding if there were strong relationships between these environmental factors and academic performance.

# %% [markdown]
# ### Key Findings

# %% [markdown]
# For hypothesis 1, there may be a negative relationship between failures and final grade based on the trends in the plotted distribution of median scores. However, hypothesis 2 may not be true because there is not a strong positive relationship between mother's education and final grade due to the fact there may be underlying bias in the students represented in the dataset.

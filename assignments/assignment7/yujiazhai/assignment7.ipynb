# %% [markdown]
# # **Assignment 7**

# %% [markdown]
# # 1. Importing Data and Libraries:

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the Wine Quality Dataset
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
df = pd.read_csv(url, sep=';')

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA)

# %%
# Explore the dataset's structure and summary statistics
# Display the first few rows and get an overview of the dataset
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Check summary statistics
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Explore data distributions with histograms
df.hist(figsize=(12, 10))
plt.show()

# %% [markdown]
# # 3. Hypothesis Formulation:

# %% [markdown]
# ### Hypothesis 1: There is a correlation between alcohol content and wine quality.

# %%
# Test Hypothesis 1: Correlation between alcohol content and wine quality
corr = df['alcohol'].corr(df['quality'])
print(f"Correlation between alcohol content and quality: {corr}")
# Out:
# Correlation between alcohol content and quality: 0.47616632400113584

# %% [markdown]
# The correlation coefficient of approximately 0.476 indicates a moderate positive correlation between alcohol content and wine quality. This correlation suggests that wines with higher alcohol content tend to receive higher quality ratings. However, it's important to note that correlation does not imply causation, and other factors may also influence wine quality.

# %% [markdown]
# ### Hypothesis 2: Wines with higher acidity have lower quality ratings.

# %%
# Test Hypothesis 2: Relationship between acidity and quality
sns.boxplot(x='quality', y='volatile acidity', data=df)
plt.title('Quality vs Volatile Acidity')
plt.show()

# %% [markdown]
# We visualized the relationship between wine quality (rated on a scale) and volatile acidity using a boxplot. The boxplot demonstrates that as wine quality increases, there is a noticeable decrease in volatile acidity levels. This indicates that wines with higher acidity (volatile acidity) generally receive lower quality ratings.
